# %% [markdown]
# # Introduction to Matplotlib

# %%
# %matplotlib inline  
# inline function help to show the graphs in the notebook itself if this was not called, the below cell would output
# an empty array
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot(); # Removes the empty array present in the above code result .

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y)

# %%
# Using the object oriented API is preferred over using the pyplot method.
# 1st method 
fig = plt.figure() # creates a figure
ax = fig.add_subplot() # add some axes
plt.show()

# %%
# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1,1,1,1]) # this adds axes to the figure
ax.plot(x,y)
plt.show()

# %%
# 3rd Method (recommended)
fig, ax = plt.subplots()
ax.plot(x,[50,100,200,250]); # add some data
type(fig) ,type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# # Matplotlib Example Workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1,2,3,4]
y = [11,22,33,44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10,10)) #(width,height)

# 3. Plot data
ax.plot(x,y)

# 4. Customize Plot
ax.set(title="Sample Plot",
      xlabel = "x-axis",
      ylabel = "y-axis")

# 5 Save & show (you save the whole figure)
fig.savefig("../Intro-to-matplotlib/sample-plot.png")

# %% [markdown]
# # Making figures with NumPy arrays
#
# We want:
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
# Create some data 
x = np.linspace(0,10,100)# Starting from 0 gives 100 equally spaced numbers till 10.
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# Use same data to make a scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %%
# Making a plot from dictionary
nut_butter_prices = {"Almond butter":10,
                    "Peanut butter": 8,
                    "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title="Dan's Nut butter Store",
      ylabel="Price($)")
# Out:
# [Text(0.5, 1.0, "Dan's Nut butter Store"), Text(0, 0.5, 'Price($)')]

# %%
fig, ax = plt.subplots();
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()));

# %%
# Make some data for histogram and plot it 
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### Two Options for Subplots

# %%
# Subplot option 1
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
# Plot to each different axis
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax4.hist(np.random.randn(1000))
# Out:
# (array([  3.,   9.,  43., 134., 223., 259., 206.,  91.,  26.,   6.]),
#  array([-3.64345546, -2.95444687, -2.26543828, -1.5764297 , -0.88742111,
#         -0.19841252,  0.49059606,  1.17960465,  1.86861324,  2.55762182,
#          3.24663041]),
#  <BarContainer object of 10 artists>)

# %%
# Subplots option 2
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax[0,0].plot(x,x/2)
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas DataFrames

# %%
import pandas as pd

# %%
# Make a DataFrame
car_sales = pd.read_csv("../car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Pandas DataFrame Visualization (Typed in google got a method to plot a pandas dataframe using the below code)
ts = pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2023',periods=1000))
ts = ts.cumsum() # cummulative sum
ts.plot()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]","")
car_sales
# Out:
# /var/folders/dm/xyq30gm95rl28z8q07p_1dj40000gn/T/ipykernel_23387/734237720.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]","")
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
car_sales['Price'] = ['4000','5000','7000','22000','3500','4500','7500','7000','6250','9700']
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
type(car_sales["Price"])
# Out:
# pandas.core.series.Series

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2023",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2023-01-01
# 1   Honda    Red          87899      4   5000 2023-01-02
# 2  Toyota   Blue          32549      3   7000 2023-01-03
# 3     BMW  Black          11179      5  22000 2023-01-04
# 4  Nissan  White         213095      4   3500 2023-01-05
# 5  Toyota  Green          99213      4   4500 2023-01-06
# 6   Honda   Blue          45698      4   7500 2023-01-07
# 7   Honda   Blue          54738      4   7000 2023-01-08
# 8  Toyota  White          60000      4   6250 2023-01-09
# 9  Nissan  White          31600      4   9700 2023-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Gives an output as string cancatenation
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  \
# 0  Toyota  White         150043      4   4000 2023-01-01
# 1   Honda    Red          87899      4   5000 2023-01-02
# 2  Toyota   Blue          32549      3   7000 2023-01-03
# 3     BMW  Black          11179      5  22000 2023-01-04
# 4  Nissan  White         213095      4   3500 2023-01-05
# 5  Toyota  Green          99213      4   4500 2023-01-06
# 6   Honda   Blue          45698      4   7500 2023-01-07
# 7   Honda   Blue          54738      4   7000 2023-01-08
# 8  Toyota  White          60000      4   6250 2023-01-09
# 9  Nissan  White          31600      4   9700 2023-01-10
#
#                                  Total Sales
# 0                                       4000
# 1                                   40005000
# 2                               400050007000
# 3                          40005000700022000
# 4                      400050007000220003500
# 5                  4000500070002200035004500
# ...

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-01-01         4000
# 1   Honda    Red          87899      4   5000 2023-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03        16000
# 3     BMW  Black          11179      5  22000 2023-01-04        38000
# 4  Nissan  White         213095      4   3500 2023-01-05        41500
# 5  Toyota  Green          99213      4   4500 2023-01-06        46000
# 6   Honda   Blue          45698      4   7500 2023-01-07        53500
# 7   Honda   Blue          54738      4   7000 2023-01-08        60500
# 8  Toyota  White          60000      4   6250 2023-01-09        66750
# 9  Nissan  White          31600      4   9700 2023-01-10        76450

# %%
# Let's plot the total sales
car_sales.plot(x="Sale Date",y="Total Sales")
# Out:
# <Axes: xlabel='Sale Date'>

# %%
# Plot scatter plot with price column as numeric.
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter")
# if these gave a type error we couk=ld change the column price data type as int to get a scatter plot using the below:
#  car_sales["Price"] = car_sales["Price"].astype(int)
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
# How about a bar graph?
x = np.random.rand(10,4)
x

# Turn it into a dataframe
df = pd.DataFrame(x,columns = ['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.120713  0.841185  0.446557  0.993244
# 1  0.518663  0.661057  0.257164  0.528194
# 2  0.277464  0.761536  0.529431  0.002372
# 3  0.483870  0.680657  0.463344  0.501043
# 4  0.255032  0.882278  0.590092  0.791872
# 5  0.317742  0.110844  0.465564  0.053670
# 6  0.541597  0.847515  0.159313  0.736397
# 7  0.497080  0.417242  0.050797  0.615954
# 8  0.522310  0.736409  0.113742  0.635140
# 9  0.790932  0.947819  0.213608  0.593977

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-01-01         4000
# 1   Honda    Red          87899      4   5000 2023-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03        16000
# 3     BMW  Black          11179      5  22000 2023-01-04        38000
# 4  Nissan  White         213095      4   3500 2023-01-05        41500
# 5  Toyota  Green          99213      4   4500 2023-01-06        46000
# 6   Honda   Blue          45698      4   7500 2023-01-07        53500
# 7   Honda   Blue          54738      4   7000 2023-01-08        60500
# 8  Toyota  White          60000      4   6250 2023-01-09        66750
# 9  Nissan  White          31600      4   9700 2023-01-10        76450

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind='bar')
# Out:
# <Axes: xlabel='Make'>

# %%
# Histogram
car_sales["Odometer (KM)"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Trying another data set
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Creating a histogram of age
heart_disease["age"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# # pyplot vs matplotlib OO method. Which one should you use?
# * When plotting something quickly, ok to use the pyplot method
# * When plotting something more advanced, us ethe OO Method

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50
over_50.head()
len(over_50)
# Out:
# 208

# %%
# Pyplot Method aka plotting directly from datframe using .plot
over_50.plot(kind='scatter',x='age',y='chol',c='target')
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
# OO Method (Object oriented method) mixed with pyplot method
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',x='age',y='chol',c='target',ax=ax);
# ax.set_xlim([45,100]); Adjusts limit of the x axis

# %%
# OO Method from scratch 
fig, ax = plt.subplots(figsize=(10,6))

# Plot the data
scatter = ax.scatter(x=over_50['age'],
                    y=over_50['chol'],
                    c=over_50['target'])
# Customize the plot
ax.set(title="Heart Disease and Cholestrol levels",
      xlabel='Age',
      ylabel='Cholestrol')

# Adding a legend
ax.legend(*scatter.legend_elements(), title='Target')

# Adding a horizontal line
ax.axhline(over_50['chol'].mean(),
          linestyle='--')

# %%
# Subplot of chol,age and thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1, figsize=(10,10), sharex=True)

# Add data on ax0
scatter = ax0.scatter(x = over_50['age'],
                     y= over_50['chol'],
                     c=over_50['target'])
# Customize ax0  
ax0.set(title='Heart Disease and  cholestrol levels',
#        xlabel='Age',
       ylabel='Cholestrol')

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(),title='Target')

# Add Meanline
ax0.axhline(y=over_50["chol"].mean(),linestyle="--")

# Adding data to ax1
scatter1 = ax1.scatter(x=over_50['age'],
                      y=over_50['thalach'],
                      c=over_50['target'])

# Adding data to ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel='Age',
       ylabel='Max Heart Rate')

# Adding legend to ax1
ax1.legend(*scatter.legend_elements(),title="Target")  

# Adding a meanline 
ax1.axhline(y=over_50["thalach"].mean(),linestyle='--')

# We see that both the below plots have the same x axis.Hence sharex=True is used above

# Adding title to the whole Figure
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# # Customizing the Matplotlib Plots

# %%
# See the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# car_sales = car_sales['Price'].astype(int)
car_sales['Price'].astype(int).plot()
# Out:
# <Axes: >

# %%
plt.style.use('seaborn-whitegrid')
# Out:
# /var/folders/dm/xyq30gm95rl28z8q07p_1dj40000gn/T/ipykernel_23387/2414357448.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
car_sales['Price'].astype(int).plot()
# Out:
# <Axes: >

# %%
plt.style.use('seaborn')
car_sales['Price'].astype(int).plot()
# Out:
# /var/folders/dm/xyq30gm95rl28z8q07p_1dj40000gn/T/ipykernel_23387/3421797355.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <Axes: >

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
plt.style.use("ggplot")
car_sales["Price"].astype(int).plot()
# Out:
# <Axes: >

# %%
# Create some data
x = np.random.randn(10,4)
x
# Out:
# array([[-0.29108127,  0.81165872,  0.5157172 , -1.07019285],
#        [ 0.13986034, -0.10690119, -0.96953888,  0.36210023],
#        [-2.13648066, -1.77999372, -0.17532948,  0.96476823],
#        [-0.66666288,  0.45829141,  0.67887932,  0.71554605],
#        [ 0.51197268, -0.67915826,  0.10230913, -0.90303174],
#        [-0.12841132, -0.02259959,  0.14483623,  0.22046615],
#        [ 0.50871125,  0.47108775, -0.71860155, -0.52053496],
#        [-0.99755779, -1.08097625,  1.13466613, -0.00763118],
#        [ 1.25844713, -1.82854077,  1.69287902,  0.50885713],
#        [-0.65705098, -0.75055827,  0.89837393, -0.65205275]])

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.291081  0.811659  0.515717 -1.070193
# 1  0.139860 -0.106901 -0.969539  0.362100
# 2 -2.136481 -1.779994 -0.175329  0.964768
# 3 -0.666663  0.458291  0.678879  0.715546
# 4  0.511973 -0.679158  0.102309 -0.903032
# 5 -0.128411 -0.022600  0.144836  0.220466
# 6  0.508711  0.471088 -0.718602 -0.520535
# 7 -0.997558 -1.080976  1.134666 -0.007631
# 8  1.258447 -1.828541  1.692879  0.508857
# 9 -0.657051 -0.750558  0.898374 -0.652053

# %%
ax = df.plot(kind='bar')
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
# Customizing my plot using the set() method
ac = df.plot(kind='bar')

# Add some labels and a title
ax.set(title='Random Number Bar Graph from dataFrame',
      xlabel="Row Number",
      ylabel="Random Number")
# Make the legend visible
ax.legend().set_visible(True)

# %%
# Set the style
plt.style.use('seaborn-whitegrid')

# OO Method from scratch 
fig, ax = plt.subplots(figsize=(10,6))

# Plot the data
scatter = ax.scatter(x=over_50['age'],
                    y=over_50['chol'],
                    c=over_50['target'],
                    cmap='winter')#this changes the colour scheme
# Customize the plot
ax.set(title="Heart Disease and Cholestrol levels",
      xlabel='Age',
      ylabel='Cholestrol')

# Adding a legend
ax.legend(*scatter.legend_elements(), title='Target')

# Adding a horizontal line
ax.axhline(over_50['chol'].mean(),
          linestyle='--')
# Out:
# /var/folders/dm/xyq30gm95rl28z8q07p_1dj40000gn/T/ipykernel_23387/4205660727.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
# Subplot of chol,age and thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1, figsize=(10,10), sharex=True)

# Add data on ax0
scatter = ax0.scatter(x = over_50['age'],
                     y= over_50['chol'],
                     c=over_50['target'],
                     cmap='winter')
# Customize ax0  
ax0.set(title='Heart Disease and  cholestrol levels',
#        xlabel='Age',
       ylabel='Cholestrol')

# Change the x-axis Limits
ax0.set_xlim([50,80]) # Cuts the extra y line off

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(),title='Target')

# Add Meanline
ax0.axhline(y=over_50["chol"].mean(),linestyle="--")

# Adding data to ax1
scatter1 = ax1.scatter(x=over_50['age'],
                      y=over_50['thalach'],
                      c=over_50['target'],
                      cmap='winter')

# Adding data to ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel='Age',
       ylabel='Max Heart Rate')
# Removing the extra line on the above x-axis of the ax1 plot
ax1.set_ylim([60,200])
# Adding legend to ax1
ax1.legend(*scatter.legend_elements(),title="Target")  

# Adding a meanline 
ax1.axhline(y=over_50["thalach"].mean(),linestyle='--')

# We see that both the below plots have the same x axis.Hence sharex=True is used above

# Adding title to the whole Figure
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %%
fig

# %%
fig.savefig("heart-disease-analysis-plot-saved-with-code.png")
